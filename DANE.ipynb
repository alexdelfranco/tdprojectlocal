# %%
# Import the necessary packages
import numpy as np
import pandas as pd
# from google.colab import auth
# import gspread
# from oauth2client.client import GoogleCredentials
# from google.colab import auth

# %%
disk_df = pd.read_csv('Mockup Planning - For Python.csv')

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

gauth = GoogleAuth()
gauth.LocalWebserverAuth() # client_secrets.json need to be in the same directory as the script
drive = GoogleDrive(gauth)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=57149566517-e37mmpk1jh6ea20rjqarmjt31dmjq3us.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %%
fileList = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file in fileList:
  print('Title: %s, ID: %s' % (file['title'], file['id']))
  # Get the folder ID that you want
  if(file['title'] == "To Share"):
      fileID = file['id']
# Out:
# Title: DATA, ID: 1shDOOUlBk6NFB-yr0bUYHQYOMiSDj7Qf
# Title: DiffEqs, ID: 1IGPg4naVRz4QE7a4htIXErjBL_vg2ejQ

# %%
def list_folder(folder_id):
    # folder_id: GoogleDriveFile['id']
    _q = {'q': "'{}' in parents and trashed=false".format(folder_id)}
    return drive.ListFile(_q).GetList()

# %%
def ListFolder(parent):
  filelist=[]
  file_list = drive.ListFile({'q': "'%s' in parents and trashed=false" % parent}).GetList()
  for f in file_list:
    if f['mimeType']=='application/vnd.google-apps.folder': # if folder
        filelist.append({"id":f['id'],"title":f['title'],"list":ListFolder(f['id'])})
    else:
        filelist.append({"title":f['title'],"title1":f['alternateLink']})
  return filelist

ListFolder('root')
# Out:
# [{'title': 'DATA',
#   'title1': 'https://drive.google.com/file/d/1shDOOUlBk6NFB-yr0bUYHQYOMiSDj7Qf/view?usp=drivesdk'},
#  {'id': '1IGPg4naVRz4QE7a4htIXErjBL_vg2ejQ',
#   'title': 'DiffEqs',
#   'list': [{'id': '1Aoa93A6d8fz2JeEU8gcHKyqR6LyypiGI',
#     'title': 'Unit 3',
#     'list': [{'id': '1N6yIMEL8LHhIvdrXzteZZIfRZQ3bt7T3',
#       'title': '!Unit 3 Overview',
#       'list': [{'title': 'Screen Shot 2020-02-19 at 11.10.01 PM.png',
#         'title1': 'https://drive.google.com/file/d/1ZV-R42OAIWiAtfHWHVWC3NaIR8SiahGv/view?usp=drivesdk'},
#        {'title': 'Screen Shot 2020-02-19 at 11.10.19 PM.png',
#         'title1': 'https://drive.google.com/file/d/1wRV33CZDsj6T93dhd5cKirmDQ-mk941z/view?usp=drivesdk'},
#        {'title': 'Screen Shot 2020-02-19 at 11.10.24 PM.png',
#         'title1': 'https://drive.google.com/file/d/1Qq3-odU0LGJi9nkBbnxnY6GpVZK5qnO8/view?usp=drivesdk'},
#        {'title': 'Screen Shot 2020-02-19 at 11.10.10 PM.png',
#         'title1': 'https://drive.google.com/file/d/1ooGd6Cen2ohje31SiCIlB_1YUnBb3-U-/view?usp=drivesdk'},
#        {'title': 'Screen Shot 2020-02-19 at 11.10.14 PM.png',
#         'title1': 'https://drive.google.com/file/d/1orpd29DOEtu2vm5V5HWdqxSlVy3uYlK4/view?usp=drivesdk'},
#        {'title': 'Screen Shot 2020-02-19 at 11.10.06 PM.png',
#         'title1': 'https://drive.google.com/file/d/1w_bo_T6v8o_WpxdFU7F_-DzBv2eWZfzA/view?usp=drivesdk'}]},
#      {'id': '1F2mxy6ipSF1T4jhU49vuCsH_zzAj26Am',
#       'title': 'Videos',
#       'list': [{'id': '1YjLocXpFNXb-FkvwFr1NFfSFk06OsHGT',
#         'title': '6.3',
#         'list': [{'title': 'stepfunctions.mp4',
#           'title1': 'https://drive.google.com/file/d/1XgeO3w3qwknMnqS63lvIqzdbSg6N95Dn/view?usp=drivesdk'}]},
#        {'id': '1cdPCs3ITaUHguLpgHv-5GEa_QRpGpj5k',
#         'title': '6.1',
#         'list': [{'title': 'laplacetransform.mp4',
#           'title1': 'https://drive.google.com/file/d/1PKM2Zj4QCcsY-y5PwTA_3n7i5DQFqNYI/view?usp=drivesdk'},
#          {'title': 'Laplace Transforms.pdf',
#           'title1': 'https://drive.google.com/file/d/1cE9U42ZOsvh17SelF274qRi38MprxEXQ/view?usp=drivesdk'}]},
#        {'id': '1E6qJaL9dgv_XtodHrNudEka3-IaUCk5u',
#         'title': '6.6',
#         'list': [{'title': 'convolution.mp4',
#           'title1': 'https://drive.google.com/file/d/1F3Yne8AJsYO44ppiTDONIJm2DMyrZs4Y/view?usp=drivesdk'}]},
#        {'id': '1x9Yje_KT52vBv-keHxL8fLoazwixPH3R',
#         'title': '5.4',
#         'list': [{'title': 'eulersingular.mp4',
#           'title1': 'https://drive.google.com/file/d/14HUC9E2Ma4Bkz6k2U1yaN8nzN2sy29nu/view?usp=drivesdk'}]},
#        {'id': '1TO50BKCGKcAsXKwRrPZSFoTX-wn__alu',
#         'title': '6.4',
#         'list': [{'title': 'diffeqdisconforcing.mp4',
#           'title1': 'https://drive.google.com/file/d/1ZEVdznkCEB09UsV5XWWtgr01dc052kNb/view?usp=drivesdk'}]},
#        {'id': '1yrvabmx36z5C6-ccdTZI9LGjhgoQ_Kws',
#         'title': '6.2',
#         'list': [{'title': 'laplaceivp.mp4',
#           'title1': 'https://drive.google.com/file/d/1v1FSAGA5GXRv2GNyzyJc4qK4yN2zi2Bg/view?usp=drivesdk'}]},
#        {'id': '1n8cnocTIbE5tLQUdAdwxe7TmTM_wyLb0',
#         'title': '5.5',
#         'list': [{'title': 'seriessingular.mp4',
#           'title1': 'https://drive.google.com/file/d/1kvVJI8wn_h_RwNIcw9fSRUumBvM-5aLM/view?usp=drivesdk'}]},
#        {'id': '1QG-J2thHhR0e5dP2zV-M2RkPNv28dSY4',
#         'title': '6.5',
#         'list': [{'title': 'impulsefunctions.mp4',
#           'title1': 'https://drive.google.com/file/d/14wdCkQXHzJ-VOg81OBv7Zc3rj4bVWjn8/view?usp=drivesdk'}]},
#        {'id': '1NwK3rNE3NiHmf19GYoElozM-cTqQ869O',
#         'title': '5.2:5.3',
#         'list': [{'title': 'seriessolutions.mp4',
#           'title1': 'https://drive.google.com/file/d/1bq6JKErFv12YE81IzdaWMFudyBnpg3ji/view?usp=drivesdk'}]}]},
#      {'id': '1uMSlazRhc7vLOR5lW5l0fDxxp4aFiLOu',
#       'title': 'Homework',
#       'list': [{'id': '1qZoOWFv-wI7wpeBE8SjB_Al7NnsUXK3D',
#         'title': '6.3',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.36.30 PM.png',
#           'title1': 'https://drive.google.com/file/d/15SV7Gu2DpDIsFQvfe-ZlvxBVTOzElPrC/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.36.20 PM.png',
#           'title1': 'https://drive.google.com/file/d/1hAKSW0K5o_yga1ZCgxXsgxP_zWQ-iTR-/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.36.15 PM.png',
#           'title1': 'https://drive.google.com/file/d/1pUWAS8ZVdE3yQhMKRmWzFO0gr_au--Sj/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.36.25 PM.png',
#           'title1': 'https://drive.google.com/file/d/1FVul1F75Gsfz0Kle-47g31LM4_QA-Red/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.34.24 PM.png',
#           'title1': 'https://drive.google.com/file/d/1LDWN8pAKuTLR1ROiqZkM6ZSa4ZR4UBfb/view?usp=drivesdk'}]},
#        {'id': '1a2ruAYyTlUd6UCD_pN2LxXlTuSmJOT4a',
#         'title': '6.6',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.37.46 PM.png',
#           'title1': 'https://drive.google.com/file/d/12SE_HyxMiEhqdESYYpin_a1PnXYarpLF/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.37.50 PM.png',
#           'title1': 'https://drive.google.com/file/d/1TOqI_ldmGjed-qswYYEI7nr19R0ls3ps/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.37.36 PM.png',
#           'title1': 'https://drive.google.com/file/d/1Paf-NugtHAnxXDW48voJw01KyF5aYFzh/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.37.42 PM.png',
#           'title1': 'https://drive.google.com/file/d/1GrQ80gxGTHH8LCDrDStr7us1Cuexu8Uo/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.37.32 PM.png',
#           'title1': 'https://drive.google.com/file/d/1XzDGsXxY5jYC1qdIzYzGd7alEeWeLxvG/view?usp=drivesdk'}]},
#        {'id': '1WLbxYOZ2PTCb8-fTvzW3czj5BYxwHXnJ',
#         'title': '6.5',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.37.13 PM.png',
#           'title1': 'https://drive.google.com/file/d/1bm4RNeQQ4cQMe1PjYHE2VPcxl_NsHCxd/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.37.21 PM.png',
#           'title1': 'https://drive.google.com/file/d/1vuULNJQDTHV2ZmGax1WMgjg68k2nwllH/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.37.25 PM.png',
#           'title1': 'https://drive.google.com/file/d/1-h8Ieb_gPm7LS1ijSHqf-W1UE2dP5-b2/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.37.17 PM.png',
#           'title1': 'https://drive.google.com/file/d/167dBtBp9eymNNGYSxcnYv-1-8KUh5pRa/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.37.09 PM.png',
#           'title1': 'https://drive.google.com/file/d/1LYQmAXgyYsG59jVfLvFboBDhQof_6DAK/view?usp=drivesdk'}]},
#        {'id': '1u5tdi60l1gib9Z9mZGSumCVJrNaBTu67',
#         'title': '6.4',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.36.52 PM.png',
#           'title1': 'https://drive.google.com/file/d/1Lr7hTKFZMOngAAmKYdgaeQdCiHb1fAvW/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.36.42 PM.png',
#           'title1': 'https://drive.google.com/file/d/1qmTeSV6p9krfZuJ7oI4CBMOKOSmaJ2AW/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.36.46 PM.png',
#           'title1': 'https://drive.google.com/file/d/1S2U24bGmEYAB-HD-03KfkqQYCf1fKVB0/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.36.57 PM.png',
#           'title1': 'https://drive.google.com/file/d/1WdtIl5TP1BXwwtQRP2nbz9n9FHL52RXN/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.37.02 PM.png',
#           'title1': 'https://drive.google.com/file/d/1skkp5y0iMGM0_CoIRuRllbi5g3lfMy20/view?usp=drivesdk'}]},
#        {'id': '16JXm6UFgG0V3saln2z7UI5rB95yHtrLe',
#         'title': '5.2:5.3',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.55.31 PM.png',
#           'title1': 'https://drive.google.com/file/d/1GN8oWXlRBW99l78YnKk6_7JMa8hIYGIV/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.55.21 PM.png',
#           'title1': 'https://drive.google.com/file/d/11dDVWY_17b0TbvpYkXZM9PPWgTsu7yIt/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.55.35 PM.png',
#           'title1': 'https://drive.google.com/file/d/1FcLfNyT_o1u6J2vpG8zFNJuLKXlGMv9q/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.55.27 PM.png',
#           'title1': 'https://drive.google.com/file/d/1pgv-8xG4YLFAC7j2nBiCuhBIGaW2-LJK/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.55.16 PM.png',
#           'title1': 'https://drive.google.com/file/d/1lpRYi0tiOVsvfeVbaOyroSQzg6OoeZCI/view?usp=drivesdk'}]},
#        {'id': '1u5AVX0tMzckSlwtbMuIeQX-xFuz794RP',
#         'title': '5.5',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.32.04 PM.png',
#           'title1': 'https://drive.google.com/file/d/1Vh7jNYkfREg_pPW7WB3nTQoF0LUPPU3Z/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.31.56 PM.png',
#           'title1': 'https://drive.google.com/file/d/1vzhWN2kAk3e2yDOVXJjiAbm9C0DDtB19/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.31.37 PM.png',
#           'title1': 'https://drive.google.com/file/d/1MJTWadDGlPL2DVAaLECELGnhI6mF1jcH/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.31.50 PM.png',
#           'title1': 'https://drive.google.com/file/d/1BdTMujJNN-ltiItzMNPFQoC5RzFTNceo/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.31.43 PM.png',
#           'title1': 'https://drive.google.com/file/d/1LFnifKMbxqVcFaTj7nDLfdwzD5DVvIV8/view?usp=drivesdk'}]},
#        {'id': '1irzGPavRyxWcnT9aoHVOOy4OuA6q05oY',
#         'title': '6.1',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.33.33 PM.png',
#           'title1': 'https://drive.google.com/file/d/1JuPSnWmdxFpqgKgkPFJ_TyIeW0S4bwlK/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.33.27 PM.png',
#           'title1': 'https://drive.google.com/file/d/1phX_E4x30uPvZKhHbROqDx-A6kVsMmP1/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.33.40 PM.png',
#           'title1': 'https://drive.google.com/file/d/11e-CxkcR0mGmluko_GeF_019kmM3gL2u/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.33.47 PM.png',
#           'title1': 'https://drive.google.com/file/d/1fz16hO5y1Abh5A2xBFo9CtsuSlu5EhCx/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.33.22 PM.png',
#           'title1': 'https://drive.google.com/file/d/11pGbd4lSTobdszstQ1d03hTQvJUpUmHn/view?usp=drivesdk'}]},
#        {'id': '1logyNvai3Y2O11huQlkouSvdkZUUft82',
#         'title': 'Quiz Ch6',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.37.58 PM.png',
#           'title1': 'https://drive.google.com/file/d/1lQRptGdSLMp3nT6X2OTcWDHRe3qo2PVg/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.38.28 PM.png',
#           'title1': 'https://drive.google.com/file/d/1BYIgs5VQZAEQR86jcD4bI28u0hogeG4E/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.38.49 PM.png',
#           'title1': 'https://drive.google.com/file/d/1CBq9V9Ij75lkSaIdqmoDqh9Ly3DHc-Pi/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.38.06 PM.png',
#           'title1': 'https://drive.google.com/file/d/1NyvdzGr1ib44Rtt5GwJtqQS5-WNgGUqS/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.38.57 PM.png',
#           'title1': 'https://drive.google.com/file/d/1KfJq_AeJAbQ_e4-YHupBBHeestq6EZ8C/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.38.14 PM.png',
#           'title1': 'https://drive.google.com/file/d/169t6xL2Ft1upJrdH5W_1r8T0p_oLtvs1/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.39.02 PM.png',
#           'title1': 'https://drive.google.com/file/d/1b2XJWLZdg3XGM4H5de-2-JinPfNsDK_y/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.38.25 PM.png',
#           'title1': 'https://drive.google.com/file/d/1BEv4zTZ-wdDmdsM5B96rlqqlF1zSUs5a/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.38.10 PM.png',
#           'title1': 'https://drive.google.com/file/d/1f22v3vTObG1RiAdqCHnCsDrGQU_ys1lc/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.38.01 PM.png',
#           'title1': 'https://drive.google.com/file/d/1R8Xw9lvAxDRBA6RrXLejbciCYbUoEg1R/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.38.54 PM.png',
#           'title1': 'https://drive.google.com/file/d/1JcbBQlC-osjJuEu04nvJBM4DcEhtf0nX/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.38.31 PM.png',
#           'title1': 'https://drive.google.com/file/d/1KdDWBAEfAy9K859v_wWOaQo6DUDMs4Dt/view?usp=drivesdk'}]},
#        {'id': '1k1c8YsaZgA69G6K-W79vhBdtRxp1dm6Z',
#         'title': '5.4',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.55.48 PM.png',
#           'title1': 'https://drive.google.com/file/d/1tWv5FBcbOC6sJdfmyLyGvEiMnREBXKhe/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.56.01 PM.png',
#           'title1': 'https://drive.google.com/file/d/1lc0bz4QFeomPm09JNfHOKpeKbHwx2RgL/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.55.57 PM.png',
#           'title1': 'https://drive.google.com/file/d/14gSORTlH_WNTnMTwy_CtI4VNfDwduMuX/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.56.05 PM.png',
#           'title1': 'https://drive.google.com/file/d/1YoMrpCg-wwgg1KhTjllyuG1oE09gWYHW/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.55.52 PM.png',
#           'title1': 'https://drive.google.com/file/d/15JfQ8SjrqPDg9wIAwIRNgLHsTx68XT3M/view?usp=drivesdk'}]},
#        {'id': '1jfjhj9x2rwACwudrSONGmBIx3XbzNd6f',
#         'title': 'Quiz Ch5',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.32.45 PM.png',
#           'title1': 'https://drive.google.com/file/d/1LqYw-xYdwzUmydCXi6j8q70ho_HsGXMm/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.33.07 PM.png',
#           'title1': 'https://drive.google.com/file/d/1JJsPwQqIIKIu2Ou3MrzGzEdWxFAnE1bO/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.32.40 PM.png',
#           'title1': 'https://drive.google.com/file/d/1s698yDgVu8DuBiqz63Z0o44ZJNekwym2/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.33.13 PM.png',
#           'title1': 'https://drive.google.com/file/d/120tOakfd9h6gFe3hVA6yndPZoG2pE9Gu/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.32.25 PM.png',
#           'title1': 'https://drive.google.com/file/d/1U1qr_EyLv5tMDiTqJL1_fRnU7SLqAm6D/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.32.31 PM.png',
#           'title1': 'https://drive.google.com/file/d/1wtzyQOXbwnLcZw8_9bdhFIZV5F32S7rR/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.32.58 PM.png',
#           'title1': 'https://drive.google.com/file/d/1ZYjjqoFTrCx2bRMywixamQpE2aXAA3fk/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.32.51 PM.png',
#           'title1': 'https://drive.google.com/file/d/1Mflw4A-YfccKw5TuiZ2ttjufatbFKGi5/view?usp=drivesdk'}]},
#        {'id': '1qGon-iUbOFwUxKcxuo0sQm3VIha97Jl8',
#         'title': '6.2',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.34.16 PM.png',
#           'title1': 'https://drive.google.com/file/d/1bv8mz9n_hLAkgg7pOQSICAmmRFruCMkL/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.34.11 PM.png',
#           'title1': 'https://drive.google.com/file/d/1j2cvpxXKWR7iOkLaf2UlOuE-NofvJEo1/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.34.04 PM.png',
#           'title1': 'https://drive.google.com/file/d/1oSx6_kQdhUPtGiKW1-8T_JlY5o7dI47l/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.33.55 PM.png',
#           'title1': 'https://drive.google.com/file/d/1y2tRHk5AJtgDolcCm1EACA6c7EsoSLf7/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.33.59 PM.png',
#           'title1': 'https://drive.google.com/file/d/1rbKkvqYp_dmJj5ONpobeQt2NJ1Z_dCRB/view?usp=drivesdk'}]},
#        {'id': '1UITtHBh9UEnrPLL4zrHF0MLyEJWLmVaD',
#         'title': '5.1',
#         'list': []}]}]},
#    {'id': '1wQxMHP0rRAhKH23IT3XCSuvZr8cMni6h',
#     'title': 'Unit 4',
#     'list': [{'id': '1GrMRX80-3z78hcX7pBwTSYh8R7lQraCi',
#       'title': 'Videos',
#       'list': [{'id': '1CRqHaSedwlBED7vsF9XZh1CqHDbsr1r3',
#         'title': '7.4',
#         'list': [{'title': 'theoryfirstordersys.mp4',
#           'title1': 'https://drive.google.com/file/d/1G7PTrYkN81rbJr9902DnOkBkinuQbxBd/view?usp=drivesdk'}]},
#        {'id': '1jVDQFZY3kEKz48pSiYXH8CNRfiLHd64P',
#         'title': '7.6',
#         'list': [{'title': 'complexeigen.mp4',
#           'title1': 'https://drive.google.com/file/d/1UogCWz2OnApfIs0ZdLHvxzOx6egAFnLI/view?usp=drivesdk'}]},
#        {'id': '1Qfd3yAAkJNmc92SbsK2sQZQCrBI6tAYv',
#         'title': '7.5',
#         'list': [{'title': 'linsysconstant.mp4',
#           'title1': 'https://drive.google.com/file/d/1dfSDbzWDf8iad79e3z3uQgrjLhVL_3Hy/view?usp=drivesdk'}]},
#        {'id': '1CPSKjdC51LaGlVi0zSEyQ_qba7vIZh_F',
#         'title': '7.3',
#         'list': [{'title': 'linindeigen.mp4',
#           'title1': 'https://drive.google.com/file/d/1hFAd5wtDxKYm0TXSseyP8I3O4M6ACfdB/view?usp=drivesdk'}]},
#        {'id': '1O-4bVqvIwztyx4VQZouc0gfr0IgaJ3cm',
#         'title': '7.9',
#         'list': [{'title': 'DIF 7.9.pdf',
#           'title1': 'https://drive.google.com/file/d/1t6LJ1Re3W2TxFmM6psZ84qV7Rs9_9rcL/view?usp=drivesdk'},
#          {'id': '1AWZAEwmhPfGUlQgNxCEoalSmtn8hwaIz',
#           'title': 'NoHomo - Linear Systems',
#           'list': [{'title': '20I.DIF.CDE.1: Lesson: Nonhomogeneous Linear Systems: Appendix - Integration Methods.webarchive',
#             'title1': 'https://drive.google.com/file/d/1O5Lf3Vvzf5pHujx3F2u8GItTg-Hseki3/view?usp=drivesdk'},
#            {'title': '20I.DIF.CDE.1: Lesson: Nonhomogeneous Linear Systems: Solving the Homogeneous Equation.webarchive',
#             'title1': 'https://drive.google.com/file/d/1HZUi-3ZedPwNut3sOKb_rF99FeHmipGh/view?usp=drivesdk'},
#            {'title': '20I.DIF.CDE.1: Lesson: Nonhomogeneous Linear Systems: Method 1 - Diagonalization.webarchive',
#             'title1': 'https://drive.google.com/file/d/1u6eoJnfwTTimZ3pRWYL6uFJwMsf0VSUY/view?usp=drivesdk'},
#            {'title': '20I.DIF.CDE.1: Lesson: Nonhomogeneous Linear Systems: Method 4 - The Laplace Transform.webarchive',
#             'title1': 'https://drive.google.com/file/d/1IYMJie8TzEgfWhFWqcJtAjwmNWEPR5UC/view?usp=drivesdk'},
#            {'title': '20I.DIF.CDE.1: Lesson: Nonhomogeneous Linear Systems: Method 3 - Variation of Parameters.webarchive',
#             'title1': 'https://drive.google.com/file/d/1T3KGIN6JFcCmuvqB-YnjH3LdykGcs8r1/view?usp=drivesdk'},
#            {'title': '20I.DIF.CDE.1: Lesson: Nonhomogeneous Linear Systems: Method 2 - Undetermined Coefficients.webarchive',
#             'title1': 'https://drive.google.com/file/d/1zh_VNjnshKR3nFM3gyn5OxDXRjULnjNS/view?usp=drivesdk'}]}]},
#        {'id': '1iQm0FpBqnqPEmMkN1uH7nRSREoMMkEpC',
#         'title': '7.8',
#         'list': [{'title': 'repeatedeigen.mp4',
#           'title1': 'https://drive.google.com/file/d/18s0Z2kA1qiKyTHAGLSru7qDmgGgvHXiH/view?usp=drivesdk'}]},
#        {'id': '1i29j1pPLXVMWnzfEbHAzWsEjpx2Gf0rv',
#         'title': '9.1',
#         'list': [{'title': 'firstordersys.mp4',
#           'title1': 'https://drive.google.com/file/d/18VyyMov11QD2tYFORhAKHE10uSn58EdY/view?usp=drivesdk'}]}]},
#      {'id': '11iIcehCdvMuqdiyclEaLUCl6iebLddAe',
#       'title': 'Homework',
#       'list': [{'id': '1bpFcxiiTcbiMfQlKE-gpk4_LTWLWvsgZ',
#         'title': '9.1',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.47.35 PM.png',
#           'title1': 'https://drive.google.com/file/d/1ROKJN5AtVjlw5cOAOHHGhU9Afyx-9DRS/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.47.39 PM.png',
#           'title1': 'https://drive.google.com/file/d/1wSUXBnmDBbq3f16iYymahqQx4KXmvZFz/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.47.43 PM.png',
#           'title1': 'https://drive.google.com/file/d/1Z95V334cXH6dNj7QZk20RWT6MiDZqpVI/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.47.28 PM.png',
#           'title1': 'https://drive.google.com/file/d/1jeJQzTcNXUqzSQFbpdR-JXLWli6BSwlz/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.47.47 PM.png',
#           'title1': 'https://drive.google.com/file/d/1JJRB5b1rEg7-Qs-LM03SxI9aNp4bNu-L/view?usp=drivesdk'}]},
#        {'id': '1TKIdIaGPAcvyePtIao8EVB_18TYoSitb',
#         'title': '7.4',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.44.32 PM.png',
#           'title1': 'https://drive.google.com/file/d/15U5VIfWazCswdsPK6TApAQ4e0BXqfcjF/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.44.35 PM.png',
#           'title1': 'https://drive.google.com/file/d/1dqVmoWF304d1ERsmb9sxUw6AInDOmVhC/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.44.44 PM.png',
#           'title1': 'https://drive.google.com/file/d/1Muec3q96PnBk5iUpyY1gTAR3CWUOnDh_/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.44.40 PM.png',
#           'title1': 'https://drive.google.com/file/d/16aOczkO17JiA1qKD3_w-CcoUp7TxM8uf/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.44.59 PM.png',
#           'title1': 'https://drive.google.com/file/d/1vFJF2kytQSKloBy2NuSp2xmUaXHo9hbQ/view?usp=drivesdk'}]},
#        {'id': '1iAyRGKnInIFm7i_FLtNwmgF5Ohn4L634',
#         'title': 'Quiz 9.1, 7.7, 7.9',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.49.00 PM.png',
#           'title1': 'https://drive.google.com/file/d/13gE1kRSzU1FM_Qa1rWUf-FormQSwE6fz/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.49.04 PM.png',
#           'title1': 'https://drive.google.com/file/d/1dSJojSUv0a46FMq6xxd2J7CIdnm-rCiY/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.49.12 PM.png',
#           'title1': 'https://drive.google.com/file/d/1LTvbpcHk0FAdEKbWwMyKO4ZOdYmPR86N/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.49.07 PM.png',
#           'title1': 'https://drive.google.com/file/d/1rr9lDx-bD-3TW86chQDaILvZfpWu8Kqx/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.48.57 PM.png',
#           'title1': 'https://drive.google.com/file/d/1pKV84NBapIjGtTfcesRxYjXmBlrzj-Mi/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.48.52 PM.png',
#           'title1': 'https://drive.google.com/file/d/165SznzadTH27tmOqExjk9Em7Hgm1yhkb/view?usp=drivesdk'}]},
#        {'id': '1HctOHiBl17xx13wRke1k6b85iNY6fwmZ',
#         'title': '7.1',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.44.01 PM.png',
#           'title1': 'https://drive.google.com/file/d/17fktjWf7ooasqaS3UcjY7qs98eK5d3kg/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.43.53 PM.png',
#           'title1': 'https://drive.google.com/file/d/1E_BzwsNzVot5rEmx7ccwFJZq4yCo60hp/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.43.42 PM.png',
#           'title1': 'https://drive.google.com/file/d/16ODDVZ1NMw4nOivI4UTsaqiYy_-g433X/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.43.57 PM.png',
#           'title1': 'https://drive.google.com/file/d/17nIcTtkKq6S6DhVQrtoFprqd-uMC0b3d/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.43.49 PM.png',
#           'title1': 'https://drive.google.com/file/d/1tOR_CZtvWsrHEzq81Of63q4VFKuPMEhs/view?usp=drivesdk'}]},
#        {'id': '1eHQWKuoQ6TVnfUPgcUkYZhZsQ6QoGXqH',
#         'title': '7.6',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.46.03 PM.png',
#           'title1': 'https://drive.google.com/file/d/13QKCD88HzCSm6MKRUJl6hbA_-kzzORZf/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.45.55 PM.png',
#           'title1': 'https://drive.google.com/file/d/1YQTwOgs8kgxvY-Vn4LqR18t_LyqLsepj/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.46.12 PM.png',
#           'title1': 'https://drive.google.com/file/d/1U9pYyKwCufxLGOhx_X1uyvDzTBk9IaGO/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.46.07 PM.png',
#           'title1': 'https://drive.google.com/file/d/19XySnl0qYVQpWtUfoLlyXhmTAMlgB-Mk/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.45.59 PM.png',
#           'title1': 'https://drive.google.com/file/d/1bj67PnYcxuBw9E40-LzDFznHTczLYi2M/view?usp=drivesdk'}]},
#        {'id': '1WQzqEXV0kZQTpf1rYvakV2Qxgo403ORy',
#         'title': '7.8',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.46.50 PM.png',
#           'title1': 'https://drive.google.com/file/d/10DQIzEadusuLvhaC9tdtH89bOjKy0Iza/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.46.19 PM.png',
#           'title1': 'https://drive.google.com/file/d/1cvhL_z1GcfHWxQTZYr1Ynsfz8409dC06/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.46.26 PM.png',
#           'title1': 'https://drive.google.com/file/d/1nQB2owv9DXGkKv_hdOdr8NErXi4fMUM0/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.46.38 PM.png',
#           'title1': 'https://drive.google.com/file/d/1--mrGDnHZXzklv5tlLzLYTFWdn436s_X/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.46.45 PM.png',
#           'title1': 'https://drive.google.com/file/d/1vdUYIaMC3aGSnY6pH3XwCKSpOX4Fj2yM/view?usp=drivesdk'}]},
#        {'id': '1WPVYtI0U7jzBRE6LuOA9X3lYEtLpHxwi',
#         'title': '7.7',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.48.08 PM.png',
#           'title1': 'https://drive.google.com/file/d/1gvRwPkKomZ37T6uCrbQQ_TtOMdZ1GJq9/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.47.54 PM.png',
#           'title1': 'https://drive.google.com/file/d/1jb0sMNljKZ0bI-SacQ9KGZh4M5Ch6Ex_/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.47.59 PM.png',
#           'title1': 'https://drive.google.com/file/d/1YXo9XESftogCcEuGdlbnE2_XQTtmzr9F/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.48.15 PM.png',
#           'title1': 'https://drive.google.com/file/d/1oB1kvj8ALcJXNd4GsuTOoHaxTd0rMM4U/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.48.19 PM.png',
#           'title1': 'https://drive.google.com/file/d/1uuVlSvv35NsIJZP2OAyRZQxhvLKKDcxj/view?usp=drivesdk'}]},
#        {'id': '1FobdtEelmQqGrYXZXgYUqaHBfC5mbAhg',
#         'title': '7.9',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.48.26 PM.png',
#           'title1': 'https://drive.google.com/file/d/1_BYYCWAp3PCIHbiWCWIvKC917B94aMUw/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.48.40 PM.png',
#           'title1': 'https://drive.google.com/file/d/1js6lqZe5TgYRALRhVLvkQ3jekNtLwOzq/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.48.44 PM.png',
#           'title1': 'https://drive.google.com/file/d/1TKIErik6NL3sdzNvf_oYzZbCuZmL4vU3/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.48.35 PM.png',
#           'title1': 'https://drive.google.com/file/d/1qyX4WoR18XrSIFap3q8vWOeK8p7U9gLx/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.48.29 PM.png',
#           'title1': 'https://drive.google.com/file/d/1kWO_cVqTUfxQaWmqQKrAzWJbqZZD5dEh/view?usp=drivesdk'}]},
#        {'id': '1Vp1jbMvCAlh1e27wx7NwgZ5ICC29lCBw',
#         'title': 'Quiz 7.1-7.4',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.45.17 PM.png',
#           'title1': 'https://drive.google.com/file/d/1RlUbcKqwJgncuCuf0KhP5w7ax78kxd0q/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.45.09 PM.png',
#           'title1': 'https://drive.google.com/file/d/1jd9YOz68f_wsvd71BeN26txYT2piJwHn/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.45.21 PM.png',
#           'title1': 'https://drive.google.com/file/d/11u3hbwhy5c39dg0LuWFvLbN1txQ3QQbd/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.45.13 PM.png',
#           'title1': 'https://drive.google.com/file/d/17xZsn6XI1mfb2vqjHqF5tYZ-4Dims8ch/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.45.25 PM.png',
#           'title1': 'https://drive.google.com/file/d/17WRXi_8gcMH8QNQ5kTnXSCNb2UAPK-OZ/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.45.05 PM.png',
#           'title1': 'https://drive.google.com/file/d/1AnSXRxht2eHZ57qsDWDXB_2XlDbeQpWW/view?usp=drivesdk'}]},
#        {'id': '15NsB8KLTD1n2NDN5-kHd0zaLprAJZWKo',
#         'title': 'Quiz 7.5-7.8',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.47.13 PM.png',
#           'title1': 'https://drive.google.com/file/d/15HjD3t6kWPDmDKUfpu9aVfRBZN0_YkJy/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.47.01 PM.png',
#           'title1': 'https://drive.google.com/file/d/1BI38HtmzuyjYvllssvpxyZ0WRl_b-lTI/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.46.57 PM.png',
#           'title1': 'https://drive.google.com/file/d/14bqa9Le1H2std3AKKIvPTALMGTLehK15/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.47.16 PM.png',
#           'title1': 'https://drive.google.com/file/d/1sQtkY508IOG2xiz-8BGPTkeuv_onv1qG/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.47.04 PM.png',
#           'title1': 'https://drive.google.com/file/d/1A7sJ5EI7FsvNtOsaPRix9sgYhH7vT8wE/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.47.08 PM.png',
#           'title1': 'https://drive.google.com/file/d/1V6brs5H1QTi7Y9aQXxuL7k_MzL1Z6DBj/view?usp=drivesdk'}]},
#        {'id': '13-8zOu7Cvx5Vt_QlrU9fpzfIOWB930pA',
#         'title': '7.5',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.45.36 PM.png',
#           'title1': 'https://drive.google.com/file/d/1CQWZlaS5JqbVukmqNtfhkZd2JOZzgHDT/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.45.31 PM.png',
#           'title1': 'https://drive.google.com/file/d/1dfJg4ktHxKCUNN57JUNRwV8p3OXdvhYV/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.45.40 PM.png',
#           'title1': 'https://drive.google.com/file/d/1NzQhL3rqLWGQkWLHih9m8Rf5lAjkDAKd/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.45.44 PM.png',
#           'title1': 'https://drive.google.com/file/d/19bS4Sgu7QDpziabM_KWq5eXIngwnniSF/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.45.48 PM.png',
#           'title1': 'https://drive.google.com/file/d/1fUvcyztwIuAarZ2W2bRPYyO5naWw5Jbg/view?usp=drivesdk'}]},
#        {'id': '1bZbbRZ_4zXMROvmyXOTXSEpIP8fr_DLC',
#         'title': '7.3',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.44.26 PM.png',
#           'title1': 'https://drive.google.com/file/d/12cWahp3M8LM-eiBv4yqaFwIpBlz8mTLd/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.44.12 PM.png',
#           'title1': 'https://drive.google.com/file/d/1jAmDmpQuiBX06FhkUCE_VbGlv9kJA369/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.44.08 PM.png',
#           'title1': 'https://drive.google.com/file/d/1adYVxYDNouhNfo5MSeDwQSc7Xt5XMTcO/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.44.22 PM.png',
#           'title1': 'https://drive.google.com/file/d/1dRpW2Qt3xLfARg4hwGqyekU6x4arJ5BM/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.44.17 PM.png',
#           'title1': 'https://drive.google.com/file/d/1digYM98f-i2iGzPTBJcJGVHwU7m3pyYX/view?usp=drivesdk'}]}]},
#      {'id': '1cVwewBXqOdwA6FGMLYGNRSzEPKEEThat',
#       'title': '!Unit 4 Overview',
#       'list': [{'title': 'Screen Shot 2020-02-19 at 11.10.38 PM.png',
#         'title1': 'https://drive.google.com/file/d/1sV9lryyW8EvqXeSSOt_074tP-L-soCIg/view?usp=drivesdk'},
#        {'title': 'Screen Shot 2020-02-19 at 11.10.42 PM.png',
#         'title1': 'https://drive.google.com/file/d/1DGk0UmjN-U_gptVms7QblOdoNBnYwYSQ/view?usp=drivesdk'},
#        {'title': 'Screen Shot 2020-02-19 at 11.10.34 PM.png',
#         'title1': 'https://drive.google.com/file/d/1F4QOHH55fBfR5LyyjLGbGhZ1dAgU5sU5/view?usp=drivesdk'},
#        {'title': 'Screen Shot 2020-02-19 at 11.10.30 PM.png',
#         'title1': 'https://drive.google.com/file/d/1QRWVD9I7FjD4Ti8ijjHKu4PK7fHO0Sr3/view?usp=drivesdk'},
#        {'title': 'Screen Shot 2020-02-19 at 11.10.46 PM.png',
#         'title1': 'https://drive.google.com/file/d/1zAysX4N9vPoa20TEp5ZaIlgXAjhLts0s/view?usp=drivesdk'}]}]},
#    {'id': '1TLwhStUJm2AvONlprZd-KTgfPPehsnCU',
#     'title': 'Unit 5',
#     'list': [{'id': '1_LNex0QBa2vlI4WG7jBH4Hc-Lmvq8OR_',
#       'title': 'Homework',
#       'list': [{'id': '1xn9LqCXOZ7jXK8VwWleUOwMYfhKlDQ1e',
#         'title': 'Quiz 9.2, 9.3',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.52.48 PM.png',
#           'title1': 'https://drive.google.com/file/d/1Qwa8g96UamioNxl4Fby80ab88dxJDrv2/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.52.29 PM.png',
#           'title1': 'https://drive.google.com/file/d/1n6wXVUCQbQ5lJ02VY51eR3GdJYQrBtBQ/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.52.37 PM.png',
#           'title1': 'https://drive.google.com/file/d/1C-4ohhRMptuHna2sj-zac8iSNRqqQUf3/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.52.33 PM.png',
#           'title1': 'https://drive.google.com/file/d/1ygzfTGiGqntOJmBRu1xJAvl6C5QA31WQ/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.52.45 PM.png',
#           'title1': 'https://drive.google.com/file/d/13IpFwW9qnRDHZbsp2wReEYjSg5C9J9wj/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.52.41 PM.png',
#           'title1': 'https://drive.google.com/file/d/1bmNUkENsFv2AKUxab1tZdLvwe2RSxK3W/view?usp=drivesdk'}]},
#        {'id': '1hA3ouQIj2oWCNF4qDNm4X2oACJQfmzTz',
#         'title': '9.2',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.50.57 PM.png',
#           'title1': 'https://drive.google.com/file/d/1X7-cQYN8G-aY88UBADHs7T7UPPoieURR/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.51.30 PM.png',
#           'title1': 'https://drive.google.com/file/d/1GTGzmUXGFBwXNqqAEyhAxA4X6FNqlL8V/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.51.45 PM.png',
#           'title1': 'https://drive.google.com/file/d/1kaEqV26eIPLzIQ38IxTmkl32DEhYqFmy/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.51.01 PM.png',
#           'title1': 'https://drive.google.com/file/d/1gFhrdx-H_0ni149Mf68HX3uMhYxtuULZ/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.51.58 PM.png',
#           'title1': 'https://drive.google.com/file/d/1wAfTXQkjVi6GDG2o9viClPmMI-qY0L91/view?usp=drivesdk'}]},
#        {'id': '1zEHYNXtSnMUSE5wiDqmOPsjc6vQCEA_G',
#         'title': 'Quiz 9.7',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.53.40 PM.png',
#           'title1': 'https://drive.google.com/file/d/1Se-8K6DwYfjCTbkNn4CQukeQkRblLGgp/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.53.31 PM.png',
#           'title1': 'https://drive.google.com/file/d/1L3lFUVMK4BRNvhaMjFETkMcf0LJPVqQs/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.53.44 PM.png',
#           'title1': 'https://drive.google.com/file/d/1K8VxoDLBNEhZELXltBSau8wXNVglHkh0/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.53.36 PM.png',
#           'title1': 'https://drive.google.com/file/d/1932ii1P5WJSaLFL5ybA6BawkTI1DoWFW/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.53.28 PM.png',
#           'title1': 'https://drive.google.com/file/d/1kcTI1G_3_g3Qul7h2ZR6WgNPPSgYEAI5/view?usp=drivesdk'}]},
#        {'id': '1OYcWhMSxxnp1V0zTnYQkfhuI00ofJva0',
#         'title': 'Non-Homogeneous Systems',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.41.23 PM.png',
#           'title1': 'https://drive.google.com/file/d/1WYK4rZyX3jFKLskTUXhQ6BJyobIlB7F8/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.41.42 PM.png',
#           'title1': 'https://drive.google.com/file/d/1_a1r6OFFrBOx9BS_21KNV9eRWweH2dAW/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.41.27 PM.png',
#           'title1': 'https://drive.google.com/file/d/1uHViJtdMoR8kgWTxRk5HAotBmjgDdz_y/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.42.29 PM.png',
#           'title1': 'https://drive.google.com/file/d/1Em7_Ly6st7-X_qq1Cgsi7YvVWHyaLMq6/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.42.03 PM.png',
#           'title1': 'https://drive.google.com/file/d/1-ByTnhIi76_GN6jJ3_meS8_SjFml1sHZ/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.42.07 PM.png',
#           'title1': 'https://drive.google.com/file/d/1jvPJhx0BqwUPUa-xkgc4uRG-RLRp9oRN/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.41.59 PM.png',
#           'title1': 'https://drive.google.com/file/d/1azP7f7fXwwn8D0UeK-d-A7xEu1EX2r-r/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.41.38 PM.png',
#           'title1': 'https://drive.google.com/file/d/1JxKmzyT3n3XoCgO7Zn6DoeobD8UH6Qho/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.42.09 PM.png',
#           'title1': 'https://drive.google.com/file/d/1Ls1yy1JQHvrgREbDk0ZXnfnlRJhK9ZA6/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.43.09 PM.png',
#           'title1': 'https://drive.google.com/file/d/1hkNPnNEax0BS2oYmmjlKqThQBm2f3gOr/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.42.15 PM.png',
#           'title1': 'https://drive.google.com/file/d/1pHmh1me-IwvFZIfKrrMl-RFzZ7TYCoEO/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.42.12 PM.png',
#           'title1': 'https://drive.google.com/file/d/1SFliI70adTQT95SHeUx9cZzNAI3e9Vmk/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.41.34 PM.png',
#           'title1': 'https://drive.google.com/file/d/1go4t0n84Omv68WrpfRcnu4YqdKcquBAt/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.42.57 PM.png',
#           'title1': 'https://drive.google.com/file/d/1LJ-XD3H1iALrZnz6sHjYrSd9hiwmXl1I/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.41.17 PM.png',
#           'title1': 'https://drive.google.com/file/d/1KyCpK_Ln2Njmxreh6WJiFCcxaMpuhDRe/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.41.49 PM.png',
#           'title1': 'https://drive.google.com/file/d/1f-TfgZrYLzl091CQEMHZga9ipZzucS8G/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.41.06 PM.png',
#           'title1': 'https://drive.google.com/file/d/1lZkwA18EFWO12znom8fEDaFbiq2qzEp-/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.42.21 PM.png',
#           'title1': 'https://drive.google.com/file/d/1PxWvHrWnI4h5t76TbTzgktvsXsTuuXte/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.43.12 PM.png',
#           'title1': 'https://drive.google.com/file/d/18wpeNYfAnNZZHaG-K5akuCRq7KalMyZO/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.41.53 PM.png',
#           'title1': 'https://drive.google.com/file/d/1CwGHFmlJAjWl27Ycl1Zmdf13qlkpwQU6/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.43.00 PM.png',
#           'title1': 'https://drive.google.com/file/d/1IH3fAkXknKiciDAKfEwStQYRuxk9zY5c/view?usp=drivesdk'}]},
#        {'id': '1dv-w3a0ZtPrv_lmDMYfrBnSJ_YpzDAlr',
#         'title': 'Quiz 9.4, 9.5',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.53.09 PM.png',
#           'title1': 'https://drive.google.com/file/d/1aFGuoibbKL40cRkGWtqC4XFKtgr14jnz/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.53.21 PM.png',
#           'title1': 'https://drive.google.com/file/d/12lJfQfrnWCVeXg2sApXorqjFeKuUT1bZ/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.52.54 PM.png',
#           'title1': 'https://drive.google.com/file/d/1dCNvTckeCuhpfUqyD8f2ROstOWbx6LYe/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.52.58 PM.png',
#           'title1': 'https://drive.google.com/file/d/1hph1gT_uzzAZ6oX-_ZCcnajqO7idb78A/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.53.03 PM.png',
#           'title1': 'https://drive.google.com/file/d/1vIR7iyRDGyciZReAhuE1G_ug5RkFKxX8/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.53.13 PM.png',
#           'title1': 'https://drive.google.com/file/d/1SChy5fSPsOvS6y4Tjsct1R21twrc5Q0l/view?usp=drivesdk'}]},
#        {'id': '1AP4UkGnNcvHr9eeLnOdzYacmhDzRbdsV',
#         'title': '9.3',
#         'list': [{'title': 'Screen Shot 2020-02-19 at 10.52.05 PM.png',
#           'title1': 'https://drive.google.com/file/d/1X6jBTYkVsxk5rCDgXUhb2a_TvFWQednB/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.52.19 PM.png',
#           'title1': 'https://drive.google.com/file/d/18LrNu-xUFer1ucM6_c2e_CYkBfULH_Tm/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.52.15 PM.png',
#           'title1': 'https://drive.google.com/file/d/1-tPwUWQjZ1DhBaABRdpYXPZ7sjjCPd_X/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.52.10 PM.png',
#           'title1': 'https://drive.google.com/file/d/1sYBrTj518276B25KS57kmy4ZRVvN1Mk4/view?usp=drivesdk'},
#          {'title': 'Screen Shot 2020-02-19 at 10.52.22 PM.png',
#           'title1': 'https://drive.google.com/file/d/1r-1ydZjAhgCuCSmEnW5zhLpmSQ8Q13ae/view?usp=drivesdk'}]}]},
#      {'id': '1BnUKT7M6t4Snqq-MKjB7Bmm8O_Bc3aHQ',
#       'title': '!Unit 5 Overview',
#       'list': [{'title': 'Screen Shot 2020-02-19 at 11.10.54 PM.png',
#         'title1': 'https://drive.google.com/file/d/17wHEi6QTWGynIo7cec8LWFT_FxWhrdHW/view?usp=drivesdk'},
#        {'title': 'Screen Shot 2020-02-19 at 11.10.58 PM.png',
#         'title1': 'https://drive.google.com/file/d/1AkhqIIzES5jAPO0Egr8a37-ltZDtmUhP/view?usp=drivesdk'},
#        {'title': 'Screen Shot 2020-02-19 at 11.10.51 PM.png',
#         'title1': 'https://drive.google.com/file/d/1tB2_nOsImF8RkIz4LTBpsY6gFwUBuVP_/view?usp=drivesdk'}]},
#      {'id': '14VxK2cg_dUj_XJir3o5nuGR2tCZw1gWW',
#       'title': 'Videos',
#       'list': [{'id': '1k_BVDugNEY1KfbjKIKydHc4LjgWqVvAj',
#         'title': '9.2',
#         'list': [{'title': 'autosysstable.mp4',
#           'title1': 'https://drive.google.com/file/d/17hHlsjBd-SMVQrif4RFLvJMGX8Qjot47/view?usp=drivesdk'}]},
#        {'id': '1oyT_gaS93QFwOQ26j9sXsfPu5YsHsr7N',
#         'title': '9.3',
#         'list': [{'title': 'locallinsys.mp4',
#           'title1': 'https://drive.google.com/file/d/1tx_mdwOuTIne6ODrf_y0cXcZb4vx0Kxb/view?usp=drivesdk'}]}]}]}]}]

# %%
drive.ListFile({file['title']: file['id']})
# Out:
# GoogleDriveFileList({'DiffEqs': '1IGPg4naVRz4QE7a4htIXErjBL_vg2ejQ'})

# %%
disk_df
# Out:
#      Mockup 1 Labels                 Mockup 1         Mockup 1 File Names  \
# 0              Rings  2MASS J16090075-1908526     2MASS_J16090075-1908526
# 1            Spirals               EM* LkCa15                     LkCa_15
# 2      Broad Shadows                 HD163296                    HD163296
# 3     Narrow Shadows                   DZ Cha                      DZ_cha
# 4          Back Side                   CQ Tau                         TAU
# 5   Ambient Material                  HD34282                34282_SPHERE
# 6            Complex                   EX Lup                      EX_Lup
# 7                NaN                   GW Ori                      GW_Ori
# 8                NaN                 HD139614  HD_139614_GPI_2018-06-08_H
# 9                NaN                    Empty                       Empty
# 10               NaN                   SU Aur                      SU_Aur
# 11               NaN                    Empty                       Empty
# 12               NaN                   IM Lup                      IM_Lup
# 13               NaN                  DoAr 25                     DoAr_25
# 14               NaN                    Empty                       Empty
# 15               NaN                    Empty                       Empty
# 16               NaN                   CS Cha                       CSCha
# 17               NaN                  HD45677                        5677
# 18               NaN                    Empty                       Empty
# 19               NaN                 HD142527                      142527
# 20               NaN                   AB Aur                      AB_Aur
# 21               NaN                      NaN                         NaN
# 22               NaN                      NaN                         NaN
# 23               NaN                      NaN                         NaN
# 24               NaN                      NaN                         NaN
# 25               NaN                      NaN                         NaN
# 26               NaN                      NaN                         NaN
# 27               NaN                      NaN                         NaN
# 28               NaN                      NaN                         NaN
# 29               NaN                      NaN                         NaN
# 30               NaN                      NaN                         NaN
# 31               NaN                      NaN                         NaN
# 32               NaN                      NaN                         NaN
# 33               NaN                      NaN                         NaN
# 34               NaN                      NaN                         NaN
# 35               NaN                      NaN                         NaN
# 36               NaN                      NaN                         NaN
# 37               NaN                      NaN                         NaN
# 38               NaN                      NaN                         NaN
# 39               NaN                      NaN                         NaN
# 40               NaN                      NaN                         NaN
# 41               NaN                      NaN                         NaN
# 42               NaN                      NaN                         NaN
# 43               NaN                      NaN                         NaN
#
#    Mockup 1 Telescope Mockup 1 Parallax Mockup 1 Mask Radius Mockup 1 Crop  \
# 0                 VLT       7.278158532                  NaN           NaN
# 1                 VLT       6.361875682                  NaN           NaN
# 2                 VLT       9.904265031                  NaN           NaN
# 3                 VLT       9.942216369                  NaN           NaN
# 4              SUBARU       6.694606068                  NaN           NaN
# 5                 VLT       3.240327672                  NaN           NaN
# 6                 VLT        6.46343174                  NaN           NaN
# 7              GEMINI       2.451004334                  NaN           NaN
# 8              GEMINI       7.483955779                  NaN           NaN
# 9               Empty             Empty                  NaN           NaN
# 10                VLT       6.370007441                  NaN           NaN
# 11              Empty             Empty                  NaN           NaN
# 12                VLT       6.417493723                  NaN           NaN
# 13                VLT       7.237937625                  NaN           NaN
# 14              Empty             Empty                  NaN           NaN
# 15              Empty             Empty                  NaN           NaN
# 16                VLT       5.925108285                  NaN           NaN
# 17             GEMINI       1.748074813                  NaN           NaN
# 18              Empty             Empty                Empty         Empty
# 19                VLT       6.279091309                  NaN           NaN
# 20                VLT       6.412709388                  NaN           NaN
# 21                NaN               NaN                  NaN           NaN
# 22                NaN               NaN                  NaN           NaN
# 23                NaN               NaN                  NaN           NaN
# 24                NaN               NaN                  NaN           NaN
# 25                NaN               NaN                  NaN           NaN
# 26                NaN               NaN                  NaN           NaN
# 27                NaN               NaN                  NaN           NaN
# 28                NaN               NaN                  NaN           NaN
# 29                NaN               NaN                  NaN           NaN
# 30                NaN               NaN                  NaN           NaN
# 31                NaN               NaN                  NaN           NaN
# 32                NaN               NaN                  NaN           NaN
# 33                NaN               NaN                  NaN           NaN
# 34                NaN               NaN                  NaN           NaN
# 35                NaN               NaN                  NaN           NaN
# 36                NaN               NaN                  NaN           NaN
# 37                NaN               NaN                  NaN           NaN
# 38                NaN               NaN                  NaN           NaN
# 39                NaN               NaN                  NaN           NaN
# 40                NaN               NaN                  NaN           NaN
# 41                NaN               NaN                  NaN           NaN
# 42                NaN               NaN                  NaN           NaN
# 43                NaN               NaN                  NaN           NaN
#
#    Mockup 1 Band Mockup 1 Smoothing   Mockup 2 Labels  ...  Mockup 10 Labels  \
# 0            NaN              False             Rings  ...             Rings
# 1            NaN              False           Spirals  ...           Spirals
# 2            NaN              False     Broad Shadows  ...     Broad Shadows
# 3            NaN              False    Narrow Shadows  ...    Narrow Shadows
# 4            NaN              False         Back Side  ...         Back Side
# 5            NaN              False  Ambient Material  ...  Ambient Material
# 6            NaN              False           Complex  ...               NaN
# 7            NaN              False               NaN  ...               NaN
# 8            NaN              False               NaN  ...               NaN
# 9            NaN              False               NaN  ...               NaN
# 10           NaN              False               NaN  ...               NaN
# 11           NaN              False               NaN  ...               NaN
# 12           NaN              False               NaN  ...               NaN
# 13           NaN              False               NaN  ...               NaN
# 14           NaN              False               NaN  ...               NaN
# 15           NaN              False               NaN  ...               NaN
# 16           NaN              False               NaN  ...               NaN
# 17           NaN              False               NaN  ...               NaN
# 18         Empty              False               NaN  ...               NaN
# 19           NaN              False               NaN  ...               NaN
# 20           NaN              False               NaN  ...               NaN
# 21           NaN                NaN               NaN  ...               NaN
# 22           NaN                NaN               NaN  ...               NaN
# 23           NaN                NaN               NaN  ...               NaN
# 24           NaN                NaN               NaN  ...               NaN
# 25           NaN                NaN               NaN  ...               NaN
# 26           NaN                NaN               NaN  ...               NaN
# 27           NaN                NaN               NaN  ...               NaN
# 28           NaN                NaN               NaN  ...               NaN
# 29           NaN                NaN               NaN  ...               NaN
# 30           NaN                NaN               NaN  ...               NaN
# 31           NaN                NaN               NaN  ...               NaN
# 32           NaN                NaN               NaN  ...               NaN
# 33           NaN                NaN               NaN  ...               NaN
# 34           NaN                NaN               NaN  ...               NaN
# 35           NaN                NaN               NaN  ...               NaN
# 36           NaN                NaN               NaN  ...               NaN
# 37           NaN                NaN               NaN  ...               NaN
# 38           NaN                NaN               NaN  ...               NaN
# 39           NaN                NaN               NaN  ...               NaN
# 40           NaN                NaN               NaN  ...               NaN
# 41           NaN                NaN               NaN  ...               NaN
# 42           NaN                NaN               NaN  ...               NaN
# 43           NaN                NaN               NaN  ...               NaN
#
#            Mockup 10 Mockup 10 Telescope  \
# 0             TW Hya                 VLT
# 1       RXJ1615-3255                 VLT
# 2            HD34700              GEMINI
# 3         Oph-IRS 48              SUBARU
# 4             GQ Lup                 VLT
# 5               SR21                 VLT
# 6           LkHa 330              SUBARU
# 7          HD135344B                 VLT
# 8             EX Lup                 VLT
# 9        WRAY 15-788                 VLT
# 10          HD143006                 VLT
# 11          HD139614              GEMINI
# 12            GG Tau                 VLT
# 13        RX J1604.3                 VLT
# 14          HD142527                 VLT
# 15          HD100453                 VLT
# 16            IM Lup                 VLT
# 17             MYLup                 VLT
# 18            PDS453                 VLT
# 19           HD34282                 VLT
# 20            DO Tau                 VLT
# 21  2MASS J1615-1921                 VLT
# 22            GW Ori              GEMINI
# 23           MWC 789              GEMINI
# 24               NaN                 NaN
# 25               NaN                 NaN
# 26               NaN                 NaN
# 27               NaN                 NaN
# 28               NaN                 NaN
# 29               NaN                 NaN
# 30               NaN                 NaN
# 31               NaN                 NaN
# 32               NaN                 NaN
# 33               NaN                 NaN
# 34               NaN                 NaN
# 35               NaN                 NaN
# 36                10                 NaN
# 37             Rings              TW Hya
# 38           Spirals              GQ Lup
# 39     Broad Shadows              EX Lup
# 40    Narrow Shadows              GG Tau
# 41         Back Side              IM Lup
# 42  Ambient Material              DO Tau
# 43               NaN                   M
#
#                                  Mockup 10 File Names Mockup 10 Parallax  \
# 0                                              TW_Hya        16.62888121
# 1                    RXJ1615-3255_SPHERE_2016-03-15_H          6.4273619
# 2                           HD_34700_GPI_2018-01-03_J        2.853230347
# 3                                              OphIRS        7.335748107
# 4                                              GQ_Lup        6.489306587
# 5                                     EM_SR21_SPHERE_           7.329848
# 6                                      LKHA330_HiCIAO        3.142522446
# 7                         HD135344B_SPHERE_2016-06-22          7.4073978
# 8                                              EX_Lup         6.46343174
# 9                                WRAY15-788_Qphi_CUBE          7.1833833
# 10                                    HD143006_SPHERE         5.97592834
# 11                         HD_139614_GPI_2018-06-08_H        7.483955779
# 12                                             GGTauA        8.591408848
# 13               RX_J1604.3-2130A_SPHERE_2017-09-17_J         6.88187666
# 14                                            _142527        6.279091309
# 15                                 HD100_Ip_Qphi_CUBE        9.635549075
# 16                                             IM_Lup        6.417493723
# 17                                      MY_Lup_SPHERE            6.36305
# 18                                      PDS453_SPHERE           7.749244
# 19                                       34282_SPHERE        3.240327672
# 20  DO_Tau_2019-11-27_12-20_Q_phi_star_pol_subtr_CUBE        7.219288747
# 21        2MASS_J16154416-1921171_SPHERE_2017-03-12_H         7.88777994
# 22                                             GW_Ori        2.451004334
# 23                                            MWC_789          1.3152777
# 24                                                NaN                NaN
# 25                                                NaN                NaN
# 26                                                NaN                NaN
# 27                                                NaN                NaN
# 28                                                NaN                NaN
# 29                                                NaN                NaN
# 30                                                NaN                NaN
# 31                                                NaN                NaN
# 32                                                NaN                NaN
# 33                                                NaN                NaN
# 34                                                NaN                NaN
# 35                                                NaN                NaN
# 36                                                NaN                NaN
# 37                                       RXJ1615-3255            HD34700
# 38                                               SR21           LkHa 330
# 39                                       WRAY 15-788            HD143006
# 40                                         RX J1604.3           HD142527
# 41                                              MYLup             PDS453
# 42                                   2MASS J1615-1921             GW Ori
# 43                                                  K                G/F
#
#    Mockup 10 Mask Radius Mockup 10 Band Mockup 10 Crop Mockup 10 Smoothing  \
# 0                     10              H            250               False
# 1                     11              H            200               False
# 2                     14              J            150               False
# 3                    6.9             Ks            180               False
# 4                      9              H            210               False
# 5                      9              H            110               False
# 6                     13              H            110               False
# 7                     12              J            110               False
# 8                    4.8              H            180                True
# 9                      9              H            120               False
# 10                     9              J            200               False
# 11                     9              H             80               False
# 12                     0              H            325               False
# 13                   8.5              J            170               False
# 14                  15.2              H            370               False
# 15                    13             I'  FORCE:140:120               False
# 16                   6.8              H            520               False
# 17                   7.5              H            180               False
# 18                   7.5              H            330               False
# 19                     9              J            230               False
# 20                    25              H            600                True
# 21                     8              H            220               False
# 22                     8              H            110               False
# 23                     8              H             90               False
# 24                   NaN            NaN            NaN                 NaN
# 25                   NaN            NaN            NaN                 NaN
# 26                   NaN            NaN            NaN                 NaN
# 27                   NaN            NaN            NaN                 NaN
# 28                   NaN            NaN            NaN                 NaN
# 29                   NaN            NaN            NaN                 NaN
# 30                   NaN            NaN            NaN                 NaN
# 31                   NaN            NaN            NaN                 NaN
# 32                   NaN            NaN            NaN                 NaN
# 33                   NaN            NaN            NaN                 NaN
# 34                   NaN            NaN            NaN                 NaN
# 35                   NaN            NaN            NaN                 NaN
# 36                   NaN            NaN            NaN                 NaN
# 37            Oph-IRS 48            NaN            NaN                 NaN
# 38             HD135344B            NaN            NaN                 NaN
# 39              HD139614            NaN            NaN                 NaN
# 40              HD100453            NaN            NaN                 NaN
# 41               HD34282            NaN            NaN                 NaN
# 42               MWC 789            NaN            NaN                 NaN
# 43                   A/B            NaN            NaN                 NaN
#
#                                   NOTES for Mockup 10
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   new polarized intensity image should be much b...
# 10                                                NaN
# 11                                                NaN
# 12  Try using LAST slice in the image cube (6th) i...
# 13                                                NaN
# 14                                                NaN
# 15   new visible light PI image should be much better
# 16            backside should be more clearly visible
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                             try a little smoothing
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24     change label of last row to "ambient material"
# 25  for all images, try this for setting the color...
# 26  include a blue/white colormap, as myriam seems...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
#
# [44 rows x 93 columns]

# %%
# Create mockup
mockup = set_mockup(disk_df,total_mockups=10,mockup_number=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f98e5bc37c8e> in <module>
#       1 # Create mockup
# ----> 2 mockup = set_mockup(disk_df,total_mockups=10,mockup_number=10)
#
# NameError: name 'set_mockup' is not defined

# %%
# Define a cube slice dictionary to catch special cases
slice_dict = {'VLT':1,'GEMINI':1,'SUBARU':5,'Special Names':['GGTauA'],'Special Slices':{'GGTauA':5}}

# %%
# Set up the file and write it to drive
mockup_images = process_fits(mockup,slice_dict,force_write=True)

# %%
os.listdir()

# %%
# Import the necessary packages
import numpy as np
import pandas as pd
from pylab import figure, cm
import matplotlib
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from astropy.io import fits
from tqdm import tqdm
from astropy.visualization import (MinMaxInterval, AsinhStretch, ImageNormalize)
import glob
import astropy.units as u
import math
from astropy.visualization.interval import ManualInterval
import astropy.convolution as conv
import os
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename
from astropy.convolution import Gaussian2DKernel
from scipy.signal import convolve as scipy_convolve
from astropy.convolution import convolve

def get_sheet_data(wb):
  sheet = wb.worksheet('For Python')
  data = sheet.get_all_values()
  df = pd.DataFrame(data)
  # Arrange Pandas dataframe
  df.columns = df.iloc[0]
  df = df.drop(df.index[0])
  df = df.reset_index()
  return df

def mockup_extract(dataframe, mockup_number):
  '''
  Input: Pandas dataframe, mockup number as an integer
  Output: Four lists: useable names, accurate names, telescope, and parallax value
  Description: Extracts and returns a dictionary of four columns of information from a given dataframe
  '''

  # Create a dictionary of dataframe column names with simple references
  col_names = {}
  col_names['names'] = 'Mockup '+str(mockup_number)
  col_names['file names'] = 'Mockup '+str(mockup_number)+' File Names'
  col_names['telescope'] = 'Mockup '+str(mockup_number)+ ' Telescope'
  col_names['parallax'] = 'Mockup '+str(mockup_number)+' Parallax'
  col_names['mask_rad'] = 'Mockup '+str(mockup_number)+' Mask Radius'
  col_names['crop'] = 'Mockup '+str(mockup_number)+' Crop'
  col_names['band'] = 'Mockup '+str(mockup_number)+' Band'
  col_names['labels'] = 'Mockup '+str(mockup_number)+' Labels'
  col_names['smoothing'] = 'Mockup '+str(mockup_number)+' Smoothing'

  # Initialize a dicitonary to return
  columns = {}
  # Determine the length of each column
  columns['length'] = 0
  for i in range(len(dataframe[col_names['names']])):
    if dataframe[col_names['names']][i] == '':
#       columns['length'] = i
      break
    else:
      columns['length'] = i+1
  # Determine the number of rows
  labels = []
  for i in range(len(dataframe[col_names['labels']])):
    if dataframe[col_names['labels']][i] == '':
      columns['label count'] = i
      break
    else:
      labels.append(dataframe[col_names['labels']][i])
  columns['labels'] = labels
  
  # For each of the eight columns of data
  for column in ['names','file names','telescope','parallax','mask_rad','crop','band','smoothing']:
    columns[column] = dataframe[col_names[column]].values.tolist()[0:columns['length']]
  # Add mockup number
  columns['number'] = mockup_number

  return columns

def mlist_extract(dataframe, total_mockup_number):
  mockups = {}  

  for mockup_number in range(1,total_mockup_number+1):
    mockup = mockup_extract(dataframe,mockup_number)
    # Add to return dictionary
    mockups['Mockup '+str(mockup_number)] = mockup
  
  mockups['number'] = total_mockup_number
  return mockups

def set_mockup(df,total_mockups,mockup_number):
  mockups = mlist_extract(df, total_mockups)
  mockup = mockups['Mockup '+str(mockup_number)]
  return mockup

def orig_pathlist(mockup):
  file_names = mockup['file names']
  # Initialize empty list for the image data
  path_list = []
  # Find the folders in the local directory
  folders = glob.glob('*/')
  # Loop through the telescope folders
#   for folder in ['VLT','GEMINI','SUBARU']:
  for folder in folders:
    # Find the image paths for each folder and append them to the initialized list
    image_paths = get_image_paths('Original_Data/'+folder)
    # Check to see if the paths have already been appended
    for path in image_paths:
      for name in file_names:
        # If they haven't been, then append
        if name in path:
          path_list.append(path)
  return path_list

def get_image_paths(folder_name):
  '''
  Input: Folder name in a specific, pre-defined parent directory, and a bool value to create a new file tree (folder)
  Output: A list of direct paths to all fits files in the input folder and possibly a new local folder
  Description: Returns the names of all fits files in a specific input folder and can create a new folder if instructed
  '''
  # Import? Probably a bad syntactical idea
  import glob
  # Define immutable parent directory
  parent_dir = '/content/drive/MyDrive/Follette Lab/Summer 2021/Projects/Transitional Disk Database/PPVII Images/DATA/'
  # Concat parent directory with the input folder name
  download_path = parent_dir+folder_name
  # Use glob package to search for all .fits files in the given folder and add them to a list
  images = glob.glob(download_path+'/*.fits')

  # Return the list of fits file paths
  return(images)

def mask_imsize_crop_calc(mockup):

  im_size = {'VLT':1024,'GEMINI':281,'SUBARU':512}
  spec_im_dict = {}
  crop_pix = {}
  image_size = {}
  mask_rad = {}

  for i in range(len(mockup['names'])):
    # Exception for special dimensions write "FORCE:total_width:crop_radius"
    if 'FORCE' in mockup['crop'][i]:
      spec_im_dict[mockup['names'][i]] = [int(mockup['crop'][i].split(':')[1]),int(mockup['crop'][i].split(':')[2])]
      crop_pix[mockup['names'][i]] = int((spec_im_dict[mockup['names'][i]][0] - spec_im_dict[mockup['names'][i]][1]) / 2)
    elif mockup['file names'][i] != 'Empty':
      crop_pix[mockup['names'][i]] = int((im_size[mockup['telescope'][i]] - int(mockup['crop'][i])) / 2)
    else: crop_pix['Empty'] = 'Empty'

  for index in range(0,mockup['length']):
    img_name = mockup['names'][index]
    if 'FORCE' not in mockup['crop'][index]:
      image_size[mockup['names'][index]] = im_size[mockup['telescope'][index]]
    else:
      image_size[mockup['names'][index]] = spec_im_dict[img_name][0]
    mask_rad[mockup['names'][index]] = float(mockup['mask_rad'][index])

  return {'Mask Radii':mask_rad,'Image Sizes':image_size,'Edge Crop':crop_pix}

def mask_remove(matrix,mockup,image_name,mask_imsize_crop):
  image_size,mask_radius = mask_imsize_crop['Image Sizes'],mask_imsize_crop['Mask Radii']
  # Defines the radius of pixels to remove from the image center (reduced by a percentage so there is overlap)
  r = mask_radius[image_name] * 0.85
  for i in range(-1*int(len(matrix)/2),int(len(matrix)/2)):
    for j in range(-1*int(len(matrix)/2),int(len(matrix)/2)):
      if (i**2 + j**2 < r**2):
        # Set pixel value to nan
        matrix[i + int(len(matrix)/2)][j + int(len(matrix)/2)] = np.nan
  return(matrix)

def edge_remove(matrix,mockup,image_name,mask_imsize_crop):
  # Defines the radius of pixels to remove from the image edge (reduced by a percentage so there is overlap)
  edge_crop = int(mask_imsize_crop['Edge Crop'][image_name] * 0.95)
  matrix[-1*edge_crop],matrix[:edge_crop],matrix[:,-1*edge_crop],matrix[:,:edge_crop] = np.nan,np.nan,np.nan,np.nan
  return(matrix)

def hdul_norm(image,slice_dict,mockup,image_name,mask_imsize_crop):
  '''
  Input: String of .fits file path
  Output: Normalized fits object with header that has the extreme values cut
  Description: Takes a .fits file path and returns a normalized and trimmed fits data file with an empty header
  '''
  # Open input fits image
  hdul = fits.open(image)
  # Extract data from the .fits file
  data = hdul[0].data
  
  # Take a specific slice of the datacube
  for telescope in ['VLT','GEMINI','SUBARU']:
    if telescope in image:
      dat = data[slice_dict[telescope]]
      break
  # Check if there is a special case for the disk
  for name in slice_dict['Special Names']:
    if name in image:
      dat = data[slice_dict['Special Slices'][name]]
      break

  # Close the header file
  hdul.close()

  # Create a new fits header file
  hdul_new = fits.HDUList()

  # Copy the fits image data
  image_cut = dat.copy()
  
  # A CAREFUL CHANGE
  image_cut = edge_remove(image_cut,mockup,image_name,mask_imsize_crop)
  image_cut = mask_remove(image_cut,mockup,image_name,mask_imsize_crop)
 
  # Set 0.03 percentile of the image to 0
  image_cut -= np.nanpercentile(image_cut,0.03)
  # Normalize the image to the 99.975th percentile
  norm_dat = image_cut/np.nanpercentile(image_cut,99.975)

  snp_med = snip_med(image_name,norm_dat,mockup,mask_imsize_crop)
  image_cut_sub = norm_dat - snp_med

  # Append the new image to the newly created fits header object
  hdul_new.append(fits.ImageHDU(data=image_cut_sub))
  
  # Return the new fits header object
  return(hdul_new)

def rec_add(string, arr, i=0):
  '''
  Input: A string and array of strings
  Output: A combined string of all the strings in the array added to the first input, separated by forward slashes
  Description: Combine a string and array of strings (file tree) into a singular filepath
  '''
  # Run as long as the string array has more elements
  if i < len(arr):
    # Return the previous input with the next element of the string
    return(rec_add(string + '/' + arr[i],arr,i+1))
  # If there are no more elements to add, return the input string
  else: return string

def add_backslash(path):
  path_arr = path.split(' ')
  full_path = ''
  for segment in path_arr:
    full_path += segment
    full_path += '\ '
  return full_path[:-2]

def insert_path(path, new_folder, position):
  '''
  Input: A filepath as a string, a folder as a string, and an integer that specifies where to insert the new folder into the filepath
  Output: The newly created filepath
  Description: Insert a new folder into a specific place in a filepath
  '''
  # Split the new path into a list of folders (i.e. the file tree)
  new_path = path.split('/')
  # Remove the original_data folder
  new_path.remove('Original_Data')
  for tlsc_folder in ['VLT','GEMINI','SUBARU']:
    if tlsc_folder in new_path:
      new_path.remove(tlsc_folder)
  # Insert a new folder into the file tree
  new_path = np.insert(new_path,position,new_folder)
  # Reassemble the filepath by recursively adding all the elements in the list
  new_path = rec_add(new_path[0],new_path[1:])

  # Return the new path
  return(new_path)

def im_name(file_name,mockup):
  for i in range(len(mockup['file names'])):
    if mockup['file names'][i] == file_name:
      return mockup['names'][i]

def process_fits(mockup,slice_dict,force_write=False):
  '''
  Input: A list of .fits file paths
  Output: Returns nothing, writes an output of fully processed .fits files to a specified filepath
  Description: Writes the normalized and scaled .fits files to a folder in google drive
  '''
  orig_paths = orig_pathlist(mockup)
  processed_image_paths = get_image_paths('Processed Images')
  mockup_paths = {}
  mockup_images = {}
  for file_name in tqdm(mockup['file names']):
    duplicate = False
    
    for path in orig_paths:
      if file_name in path:
        mockup_paths[file_name] = path

    for path in processed_image_paths:
      if file_name in path:
        duplicate = True
        if force_write:
          # Remove that file and replace it with a new one
          path = add_backslash(path)
          # !rm {path}
        else:
          # Save to mockup image dict
          hdul = fits.open(path)
          data = hdul[0].data
          hdul.close()
          mockup_images[file_name] = data
        break
    
    if (not duplicate) or (duplicate and force_write):
      # Initialize a normalized, extreme-cut fits header object
      hdul = hdul_norm(mockup_paths[file_name],slice_dict,mockup,im_name(file_name,mockup),mask_imsize_crop_calc(mockup))
      # Create a new string path for the new .fits file
      write_path = insert_path(mockup_paths[file_name],'Processed Images',-1)
      # Write the new .fits file data into a file
      hdul.writeto(write_path)
      # Save to mockup image dict
      data = hdul[0].data
      hdul.close()
      mockup_images[file_name] = data
  return mockup_images

def create_figax_strings(n=5,m=5):
  '''
  Input: The dimensions of the figure (aka the number of subplots)
  Output: Two strings, one to define the figure and axis, and the other to define an axes variable
  Description: Creates two executable strings than can be run to create a multipanel subplot with the specified dimensions
  '''
  # Initialize main string which will contain all the categorized axes
  main_str = '['
  # Enter first loop, iterating through what will be figure rows
  for i in range(n):
    # Initialize temporary axis string
    ax = '['
    # Enter second loop, iterating through what will be elements in each row
    for j in range(m):
      # If this ax is the first in a row, we don't need a comma
      if ax[-1] == '[':
        ax = ax+'ax'+str(i)+str(j)
      # If this ax isn't the first in a row, we need a comma
      else:
        ax = ax+',ax'+str(i)+str(j)
    # Add a closing bracket to the temporary axis string
    ax+=']'
    # If this axis is the first row, we don't need a comma
    if main_str[-1] == '[':
      main_str+=ax
    # If this axis isn't the first row, we need a comma
    else: main_str = main_str+','+ax
    # Add a final bracket, closing out the main string
  main_str+=']'
  # Initialize axes string and figure string
  fig_str = 'fig,'+main_str+' = plt.subplots('+str(n)+','+str(m)+',figsize=('+str(5*m)+','+str(5*n)+'),linewidth=10)'
  axes_str = 'axes = '+main_str
  # Return the axes and figure strings
  return fig_str,axes_str

def mas_to_rad(mas):
  '''
  Input: A number in miliarcseconds
  Output: A number in radians
  Description: Converts miliarcseconds to radians
  '''
  arcsec = mas / 1000
  degree = arcsec / 3600
  rad = (math.pi * degree) / 180
  return rad

def au_per_pix(pscale,dist):
  '''
  Input: The platescale of a telescope and the distance to an object images with that telescope
  Output: The distance in au per pixel
  Description: Uses the plate scale and distance to an object to calculate the distance per pixel within an image
  '''
  rad = mas_to_rad(pscale)
  pix_dist = (2 * dist) * math.tan(rad/2)
  return pix_dist

def new_out_pathgen(output_path='/content/drive/MyDrive/Follette Lab/Summer 2021/Projects/Transitional Disk Database/PPVII Images/MOCKUPS/Python_Mockups/'):
  '''
  Input: Output path (optional argument)
  Output: A path string that contains a new folder, with an incremented number compared to the previous folder
  Description: Searched within a directory for 'Mockup Round' folders and returns a path string with a newly iterated folder specified
  '''
  folder_list = glob.glob(output_path+'*')

  folder_path = folder_list[-1]
  local_folder = folder_path.split('/')[-1]
  folder_number = local_folder.split(' ')[-1]
  new_folder = 'Mockup Round '+str(int(folder_number)+1)

  new_path = output_path + new_folder

  return(new_path)

def scale_bar(mockup):
  '''
  Input: The main mockup dictionary (imported from a csv)
  Output: A dictionary with image name keys and scale bar length values
  Description: Calculates the length in pixels of scale bars on the mockup
  '''
  # Define a dictionary of plate scales for the three telescopes
  plate_scale = {'VLT':12.255,'GEMINI':14.14,'SUBARU':9.5}
  # Calculate distance to the object and the distance per pixel using the plate scale
  dist_dict = {}
  dist_per_pixel = {}
  scale_bar_pixels = {}
  for i in range(len(mockup['file names'])):
    try:
      dist_dict[mockup['file names'][i]] = float(((1000 / float(mockup['parallax'][i])) * u.pc).to(u.au) / u.au)
      dist_per_pixel[mockup['file names'][i]] = au_per_pix(plate_scale[mockup['telescope'][i]],dist_dict[mockup['file names'][i]])
      scale_bar_pixels[mockup['file names'][i]] = round(50 / dist_per_pixel[mockup['file names'][i]])
    except: ValueError
  return(scale_bar_pixels)

def snip_med(image_name,image_data,mockup,mask_imsize_crop):
  '''
  Needs to be updated
  Input: The main mockup dictionary (imported from a csv) and a dictionary of mockup images
  Output: A dictionary of mockup images with median subtracted backgrounds
  Description: Calculates the median value of image backgrounds to eventually standardize background color
  '''
  dat_snippet = []
  image_size,edge_crop = mask_imsize_crop['Image Sizes'],mask_imsize_crop['Edge Crop']

  if 'MWC_789' not in image_name and 'HD_100453_GPI_2015-04-10_J' not in image_name:
    for i in range(int(edge_crop[image_name]),int(edge_crop[image_name]+((image_size[image_name]-edge_crop[image_name])/2)/10)):
      dat_snippet_temp = []
      for j in range(int(edge_crop[image_name]),int(edge_crop[image_name]+((image_size[image_name]-edge_crop[image_name])/2)/10)):
        dat_snippet_temp.append(image_data[i][j])
      dat_snippet.append(dat_snippet_temp)
    snip_med = np.nanmedian(np.concatenate(dat_snippet))
    if np.isnan(snip_med): snip_med = 0
  else:
    for i in range(int(edge_crop[image_name]),int(edge_crop[image_name]+((image_size[image_name]-edge_crop[image_name])/2)/10)):
      dat_snippet_temp = []
      for j in range(int(edge_crop[image_name]),int(edge_crop[image_name]+((image_size[image_name]-edge_crop[image_name])/2)/10)):
        dat_snippet_temp.append(image_data[i][j])
      dat_snippet.append(dat_snippet_temp)
    snip_med = np.nanmedian(np.concatenate(dat_snippet))
    if np.isnan(snip_med): snip_med = 0
  return(snip_med)

def make_new_savepath():
  '''
  Input: N/A
  Output: A new savepath
  Description: Calculates, creates, and returns a new file path for the mockup output
  '''
  save_path = new_out_pathgen()
  os.mkdir(save_path)
  return(save_path)

def save_image(save_to_drive=False):
  # Create a new save path
  if save_to_drive:
    save_path = make_new_savepath()
    print('Save Path: '+save_path)
  else: save_path = 'null'
  return save_path

def plot_mockup(colormap,norm_alpha,mockup,mockup_images,save_path):
  '''
  Input: A colormap name, a normalization alpha parameter, a boolean instructing whether to save to drive, and a savepath to export the image
  Output: THE IMAGE
  Description: Prints the image or saves the image to a specified filepath in google drive
  '''
  # Separate width and height values
  nwidth,nheight = int(mockup['length']/mockup['label count']),int(mockup['label count'])
  # Create figure and axes
  exec(create_figax_strings(nheight,nwidth)[0],globals())
  exec(create_figax_strings(nheight,nwidth)[1],globals())
  # Set specific figure preferences
  fig.set_facecolor('white')
  fig.tight_layout(pad=-3.05)
  plt.ioff()

  # Define some helpful data dictionaries
  mimc = mask_imsize_crop_calc(mockup)
  im_size,crop_pix,mask_pix = mimc['Image Sizes'],mimc['Edge Crop'],mimc['Mask Radii']

  # Define a dictionary keying each mockup image to a scale bar length
  scale_bar_pixels = scale_bar(mockup)

  for axis in axes:
    for ax in axis: ax.axis('off')

  for i in range(nheight):
    for j in range(nwidth):
      try:
        index = nwidth*i+j
        img_name = mockup['names'][index]

        # Create dictionaries for each piece of text we want to overplot onto the image
        title_dict = {'x':crop_pix[img_name] + ((im_size[img_name] - 2*crop_pix[img_name]) * 0.05),'y':crop_pix[img_name] + ((im_size[img_name] - 2*crop_pix[img_name]) * 0.93)}
        scale_dict = {'x':crop_pix[img_name] + ((im_size[img_name] - 2*crop_pix[img_name]) * 0.05),'y':crop_pix[img_name] + ((im_size[img_name] - 2*crop_pix[img_name]) * 0.07)}
        tscope_dict = {'x':crop_pix[img_name] + ((im_size[img_name] - 2*crop_pix[img_name]) * 0.05),'y':crop_pix[img_name] + ((im_size[img_name] - 2*crop_pix[img_name]) * 0.87)}
        scale_label_dict = {'x':crop_pix[img_name] + ((im_size[img_name] - 2*crop_pix[img_name]) * 0.05),'y':crop_pix[img_name] + ((im_size[img_name] - 2*crop_pix[img_name]) * 0.1)}
        
        # Create a universal metadata dictionary for overplotted visual elements
        metdat = {'color':'white','fontsize':18,'fontstyle':'normal','fontweight':'bold'}
        
        # Plot text and visuals over the image, referencing the dictionaries above
        axes[i][j].text(title_dict['x'],title_dict['y'],mockup['names'][index],color=metdat['color'],fontsize=metdat['fontsize'],fontstyle=metdat['fontstyle'],fontweight=metdat['fontweight'])
        axes[i][j].text(tscope_dict['x'],tscope_dict['y'],mockup['telescope'][index]+' | '+mockup['band'][index]+'-Band',color=metdat['color'],fontsize=metdat['fontsize']-3,fontstyle=metdat['fontstyle'],fontweight=metdat['fontweight'])
        axes[i][j].text(scale_label_dict['x'],scale_label_dict['y'],'50 AU',color=metdat['color'],fontsize=metdat['fontsize']-6,fontstyle=metdat['fontstyle'],fontweight=metdat['fontweight'])
        axes[i][j].plot([scale_dict['x'],scale_dict['x']+scale_bar_pixels[mockup['file names'][index]]],[scale_dict['y'],scale_dict['y']],linewidth=3,color=metdat['color'])

        # Crop the images based on the universal dictionaries above
        axes[i][j].set_xlim(crop_pix[img_name],im_size[img_name] - crop_pix[img_name])
        axes[i][j].set_ylim(crop_pix[img_name],im_size[img_name] - crop_pix[img_name])
        
        # Pull out the image data
        img = mockup_images[mockup['file names'][index]]
        
        # Check if we want to smooth
        if mockup['smoothing'][index] == 'TRUE':
          # We smooth with a Gaussian kernel with x_stddev=1 (and y_stddev=1)
          # It is a 9x9 array
          kernel = Gaussian2DKernel(x_stddev=1)
          print('WE SMOOTHED IMAGE NUMBER '+str(index))

          # Convolution: scipy's direct convolution mode spreads out NaNs (see
          # panel 2 below)
          #img = scipy_convolve(img, kernel, mode='same', method='direct')
          img = convolve(img, kernel, nan_treatment='interpolate')

        # Log scale the image data (Hyperbolic Arcsine)
        norm = ImageNormalize(mockup_images[mockup['file names'][index]], interval=ManualInterval(0,1), stretch=AsinhStretch(norm_alpha))
        # Define a mesh with colormap and normalization
        axes[i][j].imshow(img,cmap=colormap,norm=norm)
        
        # Plot a circular mask
        mask = plt.Circle(((im_size[img_name])/2,(im_size[img_name])/2),radius=float(mask_pix[img_name]),color='grey',)
        mask_outline = plt.Circle((im_size[img_name]/2,im_size[img_name]/2),radius=float(mask_pix[img_name]),color='black',fill=False)

        axes[i][j].add_patch(mask)
        axes[i][j].add_patch(mask_outline)

      # Except any KeyErrors (for 'Empty' slots)
      except KeyError:
        axes[i][j].imshow([[0]],cmap = colormap)
  
  # Define Labels and Position Dictionaries
  xlabel_names = ['M','K','G/F','A/B']
  ylabel_names = mockup['labels'][::-1]
  xlabel_dict = {'x':np.arange(0,1,1/4) + 1/(2*4),'y':-0.023,'color':'black'}
  ylabel_dict = {'x':-0.023,'y':np.arange(0,1,1/mockup['label count']) + 1/(2*mockup['label count']),'color':'black'}

  for i in range(len(xlabel_names)):
    plt.text(xlabel_dict['x'][i],xlabel_dict['y'], xlabel_names[i], fontsize=35, color=xlabel_dict['color'], transform=plt.gcf().transFigure,horizontalalignment='center')
  for i in range(len(ylabel_names)):
    plt.text(ylabel_dict['x'],ylabel_dict['y'][i], ylabel_names[i], fontsize=35, color=ylabel_dict['color'], transform=plt.gcf().transFigure,horizontalalignment='right')
  
  # Draw borders around the image
  a,b,c,d = -0.005,1.015,-0.005,1.01
  line1 = matplotlib.lines.Line2D((a,b),(c,c),transform=plt.gcf().transFigure,linewidth=4,color='white')
  line2 = matplotlib.lines.Line2D((a,b),(d,d),transform=plt.gcf().transFigure,linewidth=4,color='white')
  line3 = matplotlib.lines.Line2D((a,a),(c,d),transform=plt.gcf().transFigure,linewidth=4,color='white')
  line4 = matplotlib.lines.Line2D((b,b),(c,d),transform=plt.gcf().transFigure,linewidth=4,color='white')

  fig.lines = line1,line2,line3,line4

  # Save the figure to google drive
  
  if save_path != 'null':
    plt.savefig(save_path+'/'+'Mockup '+str(mockup['number'])+' - CMap: '+colormap+' - Alpha: '+str(norm_alpha)+'.png',bbox_inches="tight",facecolor='white')
    plt.close(fig)
